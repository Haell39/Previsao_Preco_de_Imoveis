# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('data//housing.csv')
data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 0           322.0       126.0         8.3252            452600.0
# 1          2401.0      1138.0         8.3014            358500.0
# 2           496.0       177.0         7.2574            352100.0
# 3           558.0       219.0         5.6431            341300.0
# 4           565.0       259.0         3.8462            342200.0
# ...           ...         ...            ...                 ...
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity
# 0            NEAR BAY
# 1            NEAR BAY
# 2            NEAR BAY
# 3            NEAR BAY
# 4            NEAR BAY
# ...               ...
# 20635          INLAND
# 20636          INLAND
# 20637          INLAND
# 20638          INLAND
# 20639          INLAND
#
# [20640 rows x 10 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
data.dropna(inplace=True)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20433 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20433 non-null  float64
#  1   latitude            20433 non-null  float64
#  2   housing_median_age  20433 non-null  float64
#  3   total_rooms         20433 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20433 non-null  float64
#  6   households          20433 non-null  float64
#  7   median_income       20433 non-null  float64
#  8   median_house_value  20433 non-null  float64
#  9   ocean_proximity     20433 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.7+ MB

# %%
from sklearn.model_selection import train_test_split

X = data.drop(['median_house_value'], axis=1)
Y = data['median_house_value']
X
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income ocean_proximity
# 0           322.0       126.0         8.3252        NEAR BAY
# 1          2401.0      1138.0         8.3014        NEAR BAY
# 2           496.0       177.0         7.2574        NEAR BAY
# 3           558.0       219.0         5.6431        NEAR BAY
# 4           565.0       259.0         3.8462        NEAR BAY
# ...           ...         ...            ...             ...
# 20635       845.0       330.0         1.5603          INLAND
# 20636       356.0       114.0         2.5568          INLAND
# 20637      1007.0       433.0         1.7000          INLAND
# 20638       741.0       349.0         1.8672          INLAND
# 20639      1387.0       530.0         2.3886          INLAND
#
# [20433 rows x 9 columns]

# %%
Y
# Out:
# 0        452600.0
# 1        358500.0
# 2        352100.0
# 3        341300.0
# 4        342200.0
#            ...
# 20635     78100.0
# 20636     77100.0
# 20637     92300.0
# 20638     84700.0
# 20639     89400.0
# Name: median_house_value, Length: 20433, dtype: float64

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2)

# %%
train_data = X_train.join(y_train)
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 16493    -121.09     38.03                21.0       2064.0           342.0
# 6390     -118.05     34.15                32.0       5131.0           665.0
# 18198    -122.03     37.39                34.0       2600.0           650.0
# 12091    -117.28     33.85                16.0       3498.0           702.0
# 7719     -118.11     33.93                35.0       2670.0           493.0
# ...          ...       ...                 ...          ...             ...
# 5963     -117.85     34.11                25.0       9255.0          1659.0
# 1535     -122.04     37.89                33.0       2423.0           322.0
# 7871     -118.14     33.89                37.0       1159.0           238.0
# 18772    -122.29     40.43                21.0       2842.0           640.0
# 10670    -117.86     33.62                17.0       2975.0           371.0
#
#        population  households  median_income ocean_proximity  \
# 16493      1021.0       359.0         4.5170          INLAND
# 6390       1877.0       622.0         8.2004          INLAND
# 18198      1994.0       650.0         4.0223       <1H OCEAN
# 12091      2372.0       672.0         2.3229          INLAND
# 7719       1196.0       488.0         3.8427       <1H OCEAN
# ...           ...         ...            ...             ...
# 5963       4944.0      1627.0         4.5708          INLAND
# 1535        998.0       346.0         7.5349        NEAR BAY
# 7871        740.0       243.0         4.9107       <1H OCEAN
# 18772      1658.0       608.0         1.9943          INLAND
# 10670      1247.0       398.0        10.1989       <1H OCEAN
#
#        median_house_value
# 16493            152200.0
# 6390             500001.0
# 18198            250200.0
# 12091            118000.0
# 7719             283500.0
# ...                   ...
# 5963             223000.0
# 1535             349100.0
# 7871             179600.0
# 18772             59800.0
# 10670            500001.0
#
# [16346 rows x 10 columns]

# %%
train_data.hist(figsize=(20, 15))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
columns_to_drop_for_correlation = ['ocean_proximity']

#copia do dataset pra nao modificar o original
data_numeric_only = train_data.drop(columns=columns_to_drop_for_correlation, errors='ignore')

#calculando a correlação
correlation_matrix = data_numeric_only.corr()
print("Matriz de Correlação:")
display(correlation_matrix)
# Out:
# Matriz de Correlação:
#                     longitude  latitude  housing_median_age  total_rooms  \
# longitude            1.000000 -0.924259           -0.111392     0.044063
# latitude            -0.924259  1.000000            0.013191    -0.034586
# housing_median_age  -0.111392  0.013191            1.000000    -0.361545
# total_rooms          0.044063 -0.034586           -0.361545     1.000000
# total_bedrooms       0.066920 -0.063994           -0.323320     0.931333
# population           0.098469 -0.107627           -0.293865     0.857410
# households           0.054040 -0.069514           -0.304446     0.920897
# median_income       -0.015095 -0.079625           -0.117756     0.201593
# median_house_value  -0.045970 -0.143051            0.106366     0.137621
#
#                     total_bedrooms  population  households  median_income  \
# longitude                 0.066920    0.098469    0.054040      -0.015095
# latitude                 -0.063994   -0.107627   -0.069514      -0.079625
# housing_median_age       -0.323320   -0.293865   -0.304446      -0.117756
# total_rooms               0.931333    0.857410    0.920897       0.201593
# total_bedrooms            1.000000    0.876865    0.980186      -0.004387
# population                0.876865    1.000000    0.905694       0.008679
# households                0.980186    0.905694    1.000000       0.017513
# median_income            -0.004387    0.008679    0.017513       1.000000
# median_house_value        0.052276   -0.021540    0.068450       0.689352
#
#                     median_house_value
# longitude                    -0.045970
# latitude                     -0.143051
# housing_median_age            0.106366
# total_rooms                   0.137621
# total_bedrooms                0.052276
# population                   -0.021540
# households                    0.068450
# median_income                 0.689352
# median_house_value            1.000000

# %%
plt.figure(figsize=(12, 10))
sns.heatmap(correlation_matrix.corr(), annot=True, cmap='YlGnBu', fmt='.2f')
plt.title('Matriz de Correlação')
# Out:
# Text(0.5, 1.0, 'Matriz de Correlação')

# %% [markdown]
# ---
# ## Relatório Sucinto da Matriz de Correlação (Dataset de Casas da Califórnia)
# ---
#
#  -1 (correlação negativa perfeita)
#   1 (correlação positiva perfeita)
#   0 (correlação nula)
#
# ### **Principais Observações:**
#
# * **`median_income` e `median_house_value`:** Forte correlação **positiva** (0.89). Sugere que, quanto maior a renda média de uma área, maior o valor médio das casas.
# * **`total_rooms`, `total_bedrooms`, `population`, `household`:** Estas variáveis estão **fortemente correlacionadas positivamente entre si** (valores próximos a 0.99 ou 1.00). Isso é esperado, pois são contagens relacionadas ao tamanho e densidade das propriedades e comunidades. Pode indicar multicolinearidade se usadas juntas em modelos.
# * **`housing_median_age` e `total_rooms`/`total_bedrooms`/`population`/`households`:** Correlação **negativa** notável (cerca de -0.75 a -0.81). Casas mais antigas tendem a ter menos quartos, população, etc., ou estão em áreas com essas características.
# * **`latitude` e `longitude`:** Correlação **negativa** (-0.98). Como esperado, essas coordenadas são inversamente correlacionadas, pois à medida que se move para o leste (longitude crescente), a latitude geralmente diminui, e vice-versa, refletindo a geografia da Califórnia.
# * **Correlações Fracas/Negligenciáveis:** Muitas outras correlações são próximas de zero, indicando pouca ou nenhuma relação linear direta entre essas variáveis.
#
# ### **Conclusão:**
#
# A variável `median_income` é o preditor mais forte do `median_house_value` com base na correlação linear. As contagens de `rooms`, `bedrooms`, `population` e `households` são altamente inter-relacionadas e, juntamente com `housing_median_age`, refletem características estruturais e demográficas do bairro.

# %%
# taking the logs
train_data['total_rooms'] = np.log(train_data['total_rooms'] + 1)
train_data['population'] = np.log(train_data['population'] + 1)
train_data['households'] = np.log(train_data['households'] + 1)
train_data['total_bedrooms'] = np.log(train_data['total_bedrooms'] + 1)

# %%
train_data.hist(figsize=(20, 15))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
train_data.ocean_proximity.value_counts()
# Out:
# ocean_proximity
# <1H OCEAN     7198
# INLAND        5234
# NEAR OCEAN    2078
# NEAR BAY      1832
# ISLAND           4
# Name: count, dtype: int64

# %%
pd.get_dummies(train_data.ocean_proximity)
# Out:
#        <1H OCEAN  INLAND  ISLAND  NEAR BAY  NEAR OCEAN
# 16493      False    True   False     False       False
# 6390       False    True   False     False       False
# 18198       True   False   False     False       False
# 12091      False    True   False     False       False
# 7719        True   False   False     False       False
# ...          ...     ...     ...       ...         ...
# 5963       False    True   False     False       False
# 1535       False   False   False      True       False
# 7871        True   False   False     False       False
# 18772      False    True   False     False       False
# 10670       True   False   False     False       False
#
# [16346 rows x 5 columns]

# %%
train_data = train_data.join(pd.get_dummies(train_data.ocean_proximity)).drop(['ocean_proximity'], axis=1)

# %%
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 16493    -121.09     38.03                21.0     7.632886        5.837730
# 6390     -118.05     34.15                32.0     8.543251        6.501290
# 18198    -122.03     37.39                34.0     7.863651        6.478510
# 12091    -117.28     33.85                16.0     8.160232        6.555357
# 7719     -118.11     33.93                35.0     7.890208        6.202536
# ...          ...       ...                 ...          ...             ...
# 5963     -117.85     34.11                25.0     9.133027        7.414573
# 1535     -122.04     37.89                33.0     7.793174        5.777652
# 7871     -118.14     33.89                37.0     7.056175        5.476464
# 18772    -122.29     40.43                21.0     7.952615        6.463029
# 10670    -117.86     33.62                17.0     7.998335        5.918894
#
#        population  households  median_income  median_house_value  <1H OCEAN  \
# 16493    6.929517    5.886104         4.5170            152200.0      False
# 6390     7.537963    6.434547         8.2004            500001.0      False
# 18198    7.598399    6.478510         4.0223            250200.0       True
# 12091    7.771910    6.511745         2.3229            118000.0      False
# 7719     7.087574    6.192362         3.8427            283500.0       True
# ...           ...         ...            ...                 ...        ...
# 5963     8.506132    7.395108         4.5708            223000.0      False
# 1535     6.906755    5.849325         7.5349            349100.0      False
# 7871     6.608001    5.497168         4.9107            179600.0       True
# 18772    7.413970    6.411818         1.9943             59800.0      False
# 10670    7.129298    5.988961        10.1989            500001.0       True
#
#        INLAND  ISLAND  NEAR BAY  NEAR OCEAN
# 16493    True   False     False       False
# 6390     True   False     False       False
# 18198   False   False     False       False
# 12091    True   False     False       False
# 7719    False   False     False       False
# ...       ...     ...       ...         ...
# 5963     True   False     False       False
# 1535    False   False      True       False
# 7871    False   False     False       False
# 18772    True   False     False       False
# 10670   False   False     False       False
#
# [16346 rows x 14 columns]

# %%
# vendo novamente a matriz de correlação:
plt.figure(figsize=(20, 10))
sns.heatmap(train_data.corr(), annot=True, cmap='YlGnBu', fmt='.2f')
# Out:
# <Axes: >

# %%
plt.figure(figsize=(20, 10))
sns.scatterplot(x = 'latitude', y = 'longitude', data = train_data, hue = 'median_house_value', palette='coolwarm')
# Out:
# <Axes: xlabel='latitude', ylabel='longitude'>

# %%
"""Feature Engineering"""

train_data['bedroom_ratio'] = train_data['total_bedrooms'] / train_data['total_rooms']

train_data['household_rooms'] = train_data['total_rooms'] / train_data['households']

plt.figure(figsize=(15, 8))
sns.heatmap(train_data.corr(), annot=True, cmap='YlGnBu')
# Out:
# <Axes: >

# %% [markdown]
# * Por relatorios markdown pra cada img e grafico**

# %%
from sklearn.linear_model import LinearRegression

x_train, y_train = train_data.drop(['median_house_value'], axis=1), train_data['median_house_value']

reg = LinearRegression()

reg.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
import pandas as pd
import numpy as np

# Junta X_test e y_test para aplicar as mesmas transformações que foram feitas em train_data
test_data = X_test.join(y_test)

# 1. Aplica log + 1 nas colunas numéricas (como na célula In[59] para train_data)
test_data['total_rooms'] = np.log(test_data['total_rooms'] + 1)
test_data['population'] = np.log(test_data['population'] + 1)
test_data['households'] = np.log(test_data['households'] + 1)
test_data['total_bedrooms'] = np.log(test_data['total_bedrooms'] + 1)

# 2. Faz o One-Hot Encoding e remove a coluna original 'ocean_proximity'
# (EXATAMENTE como na célula In[63] para train_data)
test_data = test_data.join(pd.get_dummies(test_data.ocean_proximity)).drop(['ocean_proximity'], axis=1)

# 3. Cria as novas features 'bedroom_ratio' e 'households_rooms'
# (EXATAMENTE como na célula In[67] para train_data)
test_data['bedroom_ratio'] = test_data['total_bedrooms'] / test_data['total_rooms']
test_data['households_rooms'] = test_data['total_rooms'] / test_data['households']

# --- PARTE CRÍTICA: ALINHAR AS COLUNAS DO TESTE COM AS DO TREINO ---
# O modelo foi treinado com as colunas de X_train (features do treino).
# Precisamos garantir que o X_test que vamos usar tenha EXATAMENTE as mesmas colunas na mesma ordem.

# Primeiro, precisamos do nome das colunas que foram usadas para treinar o modelo.
# As colunas de X_train_final (o X usado no reg.fit) são a referência.
# Se você usou a célula In[68] com: x_train, y_train = train_data.drop(['median_house_value'], axis=1), train_data['median_house_value']
# Então as colunas do treino são x_train.columns
trained_feature_columns = x_train.columns # Pega as colunas do seu X de treino final

# Agora, crie a versão final do X_test com as colunas alinhadas.
# test_data.reindex(columns=...) vai garantir que as colunas sejam as mesmas e na mesma ordem.
# fill_value=0 é importante para colunas criadas pelo One-Hot Encoding que podem não aparecer
# no conjunto de teste (se uma categoria específica não estiver no teste).
X_test_final = test_data.reindex(columns=trained_feature_columns, fill_value=0)

# O y_test já está correto e não precisa de transformação, apenas para manter a conveniência de nome.
y_test_final = y_test

# Você pode rodar isso para verificar se as colunas estão alinhadas (opcional)
# print("Colunas de X_train usado no treino:", x_train.columns.tolist())
# print("Colunas de X_test final para avaliação:", X_test_final.columns.tolist())
# print("As listas de colunas são idênticas?", list(x_train.columns) == list(X_test_final.columns))

# %%
X_test = X_test_final # Atualiza X_test para a versão alinhada
y_test = y_test_final # Atualiza y_test para a versão alinhada

# %%
reg.score(X_test_final, y_test_final)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 reg.score(X_test, y_test)
#
# File D:\Documents\Ambientes\Python3.11\DSvenv\Lib\site-packages\sklearn\base.py:636, in RegressorMixin.score(self, X, y, sample_weight)
#     594 """Return :ref:`coefficient of determination <r2_score>` on test data.
#     595
#     596 The coefficient of determination, :math:`R^2`, is defined as
#    (...)    631 :class:`~sklearn.multioutput.MultiOutputRegressor`).
#     632 """
#     634 from .metrics import r2_score
# --> 636 y_pred = self.predict(X)
#     637 return r2_score(y, y_pred, sample_weight=sample_weight)
#
# File D:\Documents\Ambientes\Python3.11\DSvenv\Lib\site-packages\sklearn\linear_model\_base.py:298, in LinearModel.predict(self, X)
#     284 def predict(self, X):
#     285     """
#     286     Predict using the linear model.
#     287
#    (...)    296         Returns predicted values.
#     297     """
# --> 298     return self._decision_function(X)
#
# File D:\Documents\Ambientes\Python3.11\DSvenv\Lib\site-packages\sklearn\linear_model\_base.py:277, in LinearModel._decision_function(self, X)
#     274 def _decision_function(self, X):
#     275     check_is_fitted(self)
# --> 277     X = validate_data(self, X, accept_sparse=["csr", "csc", "coo"], reset=False)
#     278     coef_ = self.coef_
#     279     if coef_.ndim == 1:
#
# File D:\Documents\Ambientes\Python3.11\DSvenv\Lib\site-packages\sklearn\utils\validation.py:2929, in validate_data(_estimator, X, y, reset, validate_separately, skip_check_array, **check_params)
#    2845 def validate_data(
#    2846     _estimator,
#    2847     /,
#    (...)   2853     **check_params,
#    2854 ):
#    2855     """Validate input data and set or check feature names and counts of the input.
#    2856
#    2857     This helper function should be used in an estimator that requires input
#    (...)   2927         validated.
#    2928     """
# -> 2929     _check_feature_names(_estimator, X, reset=reset)
#    2930     tags = get_tags(_estimator)
#    2931     if y is None and tags.target_tags.required:
#
# File D:\Documents\Ambientes\Python3.11\DSvenv\Lib\site-packages\sklearn\utils\validation.py:2787, in _check_feature_names(estimator, X, reset)
#    2784 if not missing_names and not unexpected_names:
#    2785     message += "Feature names must be in the same order as they were in fit.\n"
# -> 2787 raise ValueError(message)
#
# ValueError: The feature names should match those that were passed during fit.
# Feature names unseen at fit time:
# - households_rooms
# Feature names seen at fit time, yet now missing:
# - household_rooms
