# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('data//housing.csv')
data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 0           322.0       126.0         8.3252            452600.0
# 1          2401.0      1138.0         8.3014            358500.0
# 2           496.0       177.0         7.2574            352100.0
# 3           558.0       219.0         5.6431            341300.0
# 4           565.0       259.0         3.8462            342200.0
# ...           ...         ...            ...                 ...
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity
# 0            NEAR BAY
# 1            NEAR BAY
# 2            NEAR BAY
# 3            NEAR BAY
# 4            NEAR BAY
# ...               ...
# 20635          INLAND
# 20636          INLAND
# 20637          INLAND
# 20638          INLAND
# 20639          INLAND
#
# [20640 rows x 10 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
data.dropna(inplace=True)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20433 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20433 non-null  float64
#  1   latitude            20433 non-null  float64
#  2   housing_median_age  20433 non-null  float64
#  3   total_rooms         20433 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20433 non-null  float64
#  6   households          20433 non-null  float64
#  7   median_income       20433 non-null  float64
#  8   median_house_value  20433 non-null  float64
#  9   ocean_proximity     20433 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.7+ MB

# %%
from sklearn.model_selection import train_test_split

X = data.drop(['median_house_value'], axis=1)
Y = data['median_house_value']
X
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income ocean_proximity
# 0           322.0       126.0         8.3252        NEAR BAY
# 1          2401.0      1138.0         8.3014        NEAR BAY
# 2           496.0       177.0         7.2574        NEAR BAY
# 3           558.0       219.0         5.6431        NEAR BAY
# 4           565.0       259.0         3.8462        NEAR BAY
# ...           ...         ...            ...             ...
# 20635       845.0       330.0         1.5603          INLAND
# 20636       356.0       114.0         2.5568          INLAND
# 20637      1007.0       433.0         1.7000          INLAND
# 20638       741.0       349.0         1.8672          INLAND
# 20639      1387.0       530.0         2.3886          INLAND
#
# [20433 rows x 9 columns]

# %%
Y
# Out:
# 0        452600.0
# 1        358500.0
# 2        352100.0
# 3        341300.0
# 4        342200.0
#            ...
# 20635     78100.0
# 20636     77100.0
# 20637     92300.0
# 20638     84700.0
# 20639     89400.0
# Name: median_house_value, Length: 20433, dtype: float64

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2)

# %%
train_data = X_train.join(y_train)
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 3492     -118.48     34.28                35.0       2132.0           368.0
# 14148    -117.08     32.73                36.0       1158.0           218.0
# 3560     -118.59     34.25                15.0       9716.0          2387.0
# 3233     -119.63     36.18                23.0        207.0            45.0
# 5019     -118.32     33.99                43.0       2028.0           479.0
# ...          ...       ...                 ...          ...             ...
# 6230     -117.94     34.06                34.0       1921.0           422.0
# 20285    -119.17     34.17                34.0       2749.0           539.0
# 15746    -122.43     37.77                52.0       3944.0          1072.0
# 11371    -117.98     33.71                26.0       1905.0           373.0
# 15326    -117.33     33.19                15.0       3672.0           845.0
#
#        population  households  median_income ocean_proximity  \
# 3492       1128.0       341.0         5.3107       <1H OCEAN
# 14148       619.0       233.0         3.6125      NEAR OCEAN
# 3560       4992.0      2225.0         3.6231       <1H OCEAN
# 3233        171.0        50.0         2.4286          INLAND
# 5019       1074.0       394.0         2.5909       <1H OCEAN
# ...           ...         ...            ...             ...
# 6230       1230.0       447.0         3.6648       <1H OCEAN
# 20285      2330.0       559.0         4.2137      NEAR OCEAN
# 15746      1913.0       973.0         2.9567        NEAR BAY
# 11371      1098.0       368.0         4.8611       <1H OCEAN
# 15326      1827.0       796.0         2.9716      NEAR OCEAN
#
#        median_house_value
# 3492             227100.0
# 14148            122500.0
# 3560             193300.0
# 3233             100000.0
# 5019              98700.0
# ...                   ...
# 6230             193900.0
# 20285            185600.0
# 15746            425000.0
# 11371            229600.0
# 15326            173600.0
#
# [16346 rows x 10 columns]

# %%
train_data.hist(figsize=(20, 15))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
columns_to_drop_for_correlation = ['ocean_proximity']

#copia do dataset pra nao modificar o original
data_numeric_only = train_data.drop(columns=columns_to_drop_for_correlation, errors='ignore')

#calculando a correlação
correlation_matrix = data_numeric_only.corr()
print("Matriz de Correlação:")
display(correlation_matrix)
# Out:
# Matriz de Correlação:
#                     longitude  latitude  housing_median_age  total_rooms  \
# longitude            1.000000 -0.923633           -0.103686     0.042430
# latitude            -0.923633  1.000000            0.005747    -0.033577
# housing_median_age  -0.103686  0.005747            1.000000    -0.355091
# total_rooms          0.042430 -0.033577           -0.355091     1.000000
# total_bedrooms       0.067337 -0.065126           -0.314128     0.928738
# population           0.095824 -0.105701           -0.291968     0.859920
# households           0.053649 -0.070096           -0.296187     0.916962
# median_income       -0.013092 -0.082204           -0.114413     0.198108
# median_house_value  -0.043632 -0.146982            0.109934     0.135396
#
#                     total_bedrooms  population  households  median_income  \
# longitude                 0.067337    0.095824    0.053649      -0.013092
# latitude                 -0.065126   -0.105701   -0.070096      -0.082204
# housing_median_age       -0.314128   -0.291968   -0.296187      -0.114413
# total_rooms               0.928738    0.859920    0.916962       0.198108
# total_bedrooms            1.000000    0.881981    0.979181      -0.009787
# population                0.881981    1.000000    0.911738       0.006554
# households                0.979181    0.911738    1.000000       0.012424
# median_income            -0.009787    0.006554    0.012424       1.000000
# median_house_value        0.052086   -0.022153    0.067669       0.683766
#
#                     median_house_value
# longitude                    -0.043632
# latitude                     -0.146982
# housing_median_age            0.109934
# total_rooms                   0.135396
# total_bedrooms                0.052086
# population                   -0.022153
# households                    0.067669
# median_income                 0.683766
# median_house_value            1.000000

# %%
plt.figure(figsize=(12, 10))
sns.heatmap(correlation_matrix.corr(), annot=True, cmap='YlGnBu', fmt='.2f')
plt.title('Matriz de Correlação')
# Out:
# Text(0.5, 1.0, 'Matriz de Correlação')

# %% [markdown]
# ---
# ## Relatório Sucinto da Matriz de Correlação (Dataset de Casas da Califórnia)
# ---
#
#  -1 (correlação negativa perfeita)
#   1 (correlação positiva perfeita)
#   0 (correlação nula)
#
# ### **Principais Observações:**
#
# * **`median_income` e `median_house_value`:** Forte correlação **positiva** (0.89). Sugere que, quanto maior a renda média de uma área, maior o valor médio das casas.
# * **`total_rooms`, `total_bedrooms`, `population`, `household`:** Estas variáveis estão **fortemente correlacionadas positivamente entre si** (valores próximos a 0.99 ou 1.00). Isso é esperado, pois são contagens relacionadas ao tamanho e densidade das propriedades e comunidades. Pode indicar multicolinearidade se usadas juntas em modelos.
# * **`housing_median_age` e `total_rooms`/`total_bedrooms`/`population`/`households`:** Correlação **negativa** notável (cerca de -0.75 a -0.81). Casas mais antigas tendem a ter menos quartos, população, etc., ou estão em áreas com essas características.
# * **`latitude` e `longitude`:** Correlação **negativa** (-0.98). Como esperado, essas coordenadas são inversamente correlacionadas, pois à medida que se move para o leste (longitude crescente), a latitude geralmente diminui, e vice-versa, refletindo a geografia da Califórnia.
# * **Correlações Fracas/Negligenciáveis:** Muitas outras correlações são próximas de zero, indicando pouca ou nenhuma relação linear direta entre essas variáveis.
#
# ### **Conclusão:**
#
# A variável `median_income` é o preditor mais forte do `median_house_value` com base na correlação linear. As contagens de `rooms`, `bedrooms`, `population` e `households` são altamente inter-relacionadas e, juntamente com `housing_median_age`, refletem características estruturais e demográficas do bairro.

# %%
# taking the logs
train_data['total_rooms'] = np.log(train_data['total_rooms'] + 1)
train_data['population'] = np.log(train_data['population'] + 1)
train_data['households'] = np.log(train_data['households'] + 1)
train_data['total_bedrooms'] = np.log(train_data['total_bedrooms'] + 1)

# %%
train_data.hist(figsize=(20, 15))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
train_data.ocean_proximity.value_counts()
# Out:
# ocean_proximity
# <1H OCEAN     7202
# INLAND        5233
# NEAR OCEAN    2122
# NEAR BAY      1785
# ISLAND           4
# Name: count, dtype: int64

# %%
pd.get_dummies(train_data.ocean_proximity)
# Out:
#        <1H OCEAN  INLAND  ISLAND  NEAR BAY  NEAR OCEAN
# 3492        True   False   False     False       False
# 14148      False   False   False     False        True
# 3560        True   False   False     False       False
# 3233       False    True   False     False       False
# 5019        True   False   False     False       False
# ...          ...     ...     ...       ...         ...
# 6230        True   False   False     False       False
# 20285      False   False   False     False        True
# 15746      False   False   False      True       False
# 11371       True   False   False     False       False
# 15326      False   False   False     False        True
#
# [16346 rows x 5 columns]

# %%
train_data = train_data.join(pd.get_dummies(train_data.ocean_proximity)).drop(['ocean_proximity'], axis=1)

# %%
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 3492     -118.48     34.28                35.0     7.665285        5.910797
# 14148    -117.08     32.73                36.0     7.055313        5.389072
# 3560     -118.59     34.25                15.0     9.181632        7.778211
# 3233     -119.63     36.18                23.0     5.337538        3.828641
# 5019     -118.32     33.99                43.0     7.615298        6.173786
# ...          ...       ...                 ...          ...             ...
# 6230     -117.94     34.06                34.0     7.561122        6.047372
# 20285    -119.17     34.17                34.0     7.919356        6.291569
# 15746    -122.43     37.77                52.0     8.280204        6.978214
# 11371    -117.98     33.71                26.0     7.552762        5.924256
# 15326    -117.33     33.19                15.0     8.208764        6.740519
#
#        population  households  median_income  median_house_value  <1H OCEAN  \
# 3492     7.029088    5.834811         5.3107            227100.0       True
# 14148    6.429719    5.455321         3.6125            122500.0      False
# 3560     8.515792    7.707962         3.6231            193300.0       True
# 3233     5.147494    3.931826         2.4286            100000.0      False
# 5019     6.980076    5.978886         2.5909             98700.0       True
# ...           ...         ...            ...                 ...        ...
# 6230     7.115582    6.104793         3.6648            193900.0       True
# 20285    7.754053    6.327937         4.2137            185600.0      False
# 15746    7.556951    6.881411         2.9567            425000.0      False
# 11371    7.002156    5.910797         4.8611            229600.0       True
# 15326    7.510978    6.680855         2.9716            173600.0      False
#
#        INLAND  ISLAND  NEAR BAY  NEAR OCEAN
# 3492    False   False     False       False
# 14148   False   False     False        True
# 3560    False   False     False       False
# 3233     True   False     False       False
# 5019    False   False     False       False
# ...       ...     ...       ...         ...
# 6230    False   False     False       False
# 20285   False   False     False        True
# 15746   False   False      True       False
# 11371   False   False     False       False
# 15326   False   False     False        True
#
# [16346 rows x 14 columns]

# %%
# vendo novamente a matriz de correlação:
plt.figure(figsize=(20, 10))
sns.heatmap(train_data.corr(), annot=True, cmap='YlGnBu', fmt='.2f')
# Out:
# <Axes: >

# %%
plt.figure(figsize=(20, 10))
sns.scatterplot(x = 'latitude', y = 'longitude', data = train_data, hue = 'median_house_value', palette='coolwarm')
# Out:
# <Axes: xlabel='latitude', ylabel='longitude'>

# %%
"""Feature Engineering"""

train_data['bedroom_ratio'] = train_data['total_bedrooms'] / train_data['total_rooms']

train_data['household_rooms'] = train_data['total_rooms'] / train_data['households']

plt.figure(figsize=(15, 8))
sns.heatmap(train_data.corr(), annot=True, cmap='YlGnBu')
# Out:
# <Axes: >

# %% [markdown]
# * Por relatorios markdown pra cada img e grafico**
